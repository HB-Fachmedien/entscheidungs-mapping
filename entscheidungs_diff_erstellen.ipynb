# %%
import pandas as pd

# %%
alte_tabelle = pd.read_csv('neu_EntscheidungsTabelle.csv', sep='\t', encoding='utf-8')
# Out:
# C:\Users\maibuecher\AppData\Local\conda\conda\envs\basemap-env\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (5,6,7,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
alte_tabelle.head()
# Out:
#        docid                                              title instdocdate  \
# 0  RS0812543  Bindungswirkung von Beschlüssen des Plenums - ...  1951-10-23
# 1  RS0800815                                       Rechtsmittel  1951-11-08
# 2  RS0812565  Verfassungsrechtliche Anforderungen an die Ver...  1952-05-21
# 3  RS0812593  Verfassungswidrigkeit der Haftentschädigungsre...  1953-07-01
# 4  RS0812608        Verfassungsmäßigkeit des Art. 117 Abs. 2 GG  1953-12-18
#
#   alt_docid1 alt_docid2 alt_docid3 alt_docid4 alt_docid5  \
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#
#                       extid    inst  ... instdocnr2  instdocnr3 instdocnr4  \
# 0  Deubner_DRSP_1996/006393  BVerfG  ...        NaN         NaN        NaN
# ...

# %%
alte_tabelle.shape
# Out:
# (49548, 24)

# %%
neue_tabelle = pd.read_csv('neu_Juni_2019_EntscheidungsTabelle.csv', sep='\t', encoding='utf-8')
# Out:
# C:\Users\maibuecher\AppData\Local\conda\conda\envs\basemap-env\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
neue_tabelle.shape
# Out:
# (50558, 24)

# %%
alte_tabelle.drop(columns=['wird_gemappt'], inplace=True)
neue_tabelle.drop(columns=['wird_gemappt'], inplace=True)

# %%
diff_df = pd.concat([alte_tabelle, neue_tabelle], ignore_index=True)

# %%
diff_df.shape
# Out:
# (100106, 23)

# %%
diff_df.head()
# Out:
#        docid                                              title instdocdate  \
# 0  RS0812543  Bindungswirkung von Beschlüssen des Plenums - ...  1951-10-23
# 1  RS0800815                                       Rechtsmittel  1951-11-08
# 2  RS0812565  Verfassungsrechtliche Anforderungen an die Ver...  1952-05-21
# 3  RS0812593  Verfassungswidrigkeit der Haftentschädigungsre...  1953-07-01
# 4  RS0812608        Verfassungsmäßigkeit des Art. 117 Abs. 2 GG  1953-12-18
#
#   alt_docid1 alt_docid2 alt_docid3 alt_docid4 alt_docid5  \
# 0        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN
#
#                       extid    inst  ...    instdocnr1  instdocnr2 instdocnr3  \
# 0  Deubner_DRSP_1996/006393  BVerfG  ...    2 BvG 1/51         NaN        NaN
# ...

# %%
diff_df.loc[diff_df['docid']=='RS0812543']
# Out:
#            docid                                              title  \
# 0      RS0812543  Bindungswirkung von Beschlüssen des Plenums - ...
# 49548  RS0812543  Bindungswirkung von Beschlüssen des Plenums - ...
#
#       instdocdate alt_docid1 alt_docid2 alt_docid3 alt_docid4 alt_docid5  \
# 0      1951-10-23        NaN        NaN        NaN        NaN        NaN
# 49548  1951-10-23        NaN        NaN        NaN        NaN        NaN
#
#                           extid    inst  ...  instdocnr1  instdocnr2  \
# 0      Deubner_DRSP_1996/006393  BVerfG  ...  2 BvG 1/51         NaN
# 49548  Deubner_DRSP_1996/006393  BVerfG  ...  2 BvG 1/51         NaN
#
#       instdocnr3 instdocnr4 instdocnr5 instdocnr6 instdocnr7  instdocnr8  \
# 0            NaN        NaN        NaN        NaN        NaN         NaN
# 49548        NaN        NaN        NaN        NaN        NaN         NaN
#
#        instdocnr9  instdocaddnrs
# 0             NaN            NaN
# 49548         NaN            NaN
#
# ...

# %%
res = diff_df.drop_duplicates(keep=False)

# %%
res.head()
# Out:
#            docid                                              title  \
# 22253  RS0705664  Befristungsrecht - Befristeter Arbeitsvertrag;...
# 35870  RS0703093  Benachteiligung eines schwerbehinderten Bewerb...
# 35932  RS0703094  Arbeitsentgelt; Vergütung von Mehrarbeit; Verg...
# 36283  RS0703096  Umfang des Forderungsübergangs bei "Hartz IV-L...
# 36876  RS0703098  Verfall des tariflichen Mehrurlaubs gemäß § 26...
#
#       instdocdate alt_docid1 alt_docid2 alt_docid3 alt_docid4 alt_docid5  \
# 22253  2008-02-20  DB0295520        NaN        NaN        NaN        NaN
# 35870  2012-02-16  DB0474691        NaN        NaN        NaN        NaN
# 35932  2012-02-22  DB0480391        NaN        NaN        NaN        NaN
# 36283  2012-03-21  DB0480253        NaN        NaN        NaN        NaN
# 36876  2012-05-22  DB0487783        NaN        NaN        NaN        NaN
#
#                           extid inst  ...    instdocnr1  instdocnr2  \
# ...

# %%
res.to_csv('finales_mapping.csv', sep="\t", encoding='utf-8')
